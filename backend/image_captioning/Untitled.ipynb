# %%
import pandas as pd
import os

# %%
# %config Completer.use_jedi = False

# %%
df = pd.read_csv("test/results.csv")

# %%
df
# Out:
#     Unnamed: 0                                        image_files  \
# 0            0  image_captioning/test/uploaded/Popeyes with no...
# 1            1  image_captioning/test/uploaded/Popeyes with no...
# 2            2  image_captioning/test/uploaded/Popeyes with no...
# 3            3  image_captioning/test/uploaded/Popeyes with no...
# 4            4  image_captioning/test/uploaded/Popeyes with no...
# 5            5  image_captioning/test/uploaded/Popeyes with no...
# 6            6  image_captioning/test/uploaded/Popeyes with no...
# 7            7  image_captioning/test/uploaded/Popeyes with no...
# 8            8  image_captioning/test/uploaded/Popeyes with no...
# 9            9  image_captioning/test/uploaded/Popeyes with no...
# 10          10  image_captioning/test/uploaded/Popeyes with no...
# 11          11  image_captioning/test/uploaded/Popeyes with no...
# 12          12  image_captioning/test/uploaded/Popeyes with no...
# ...

# %%
df = df.sort_values(by=["timestamps"])
df
# Out:
#     Unnamed: 0                                        image_files  \
# 32          32  image_captioning/test/uploaded/Popeyes with no...
# 26          26  image_captioning/test/uploaded/Popeyes with no...
# 29          29  image_captioning/test/uploaded/Popeyes with no...
# 20          20  image_captioning/test/uploaded/Popeyes with no...
# 3            3  image_captioning/test/uploaded/Popeyes with no...
# 22          22  image_captioning/test/uploaded/Popeyes with no...
# 9            9  image_captioning/test/uploaded/Popeyes with no...
# 15          15  image_captioning/test/uploaded/Popeyes with no...
# 13          13  image_captioning/test/uploaded/Popeyes with no...
# 11          11  image_captioning/test/uploaded/Popeyes with no...
# 7            7  image_captioning/test/uploaded/Popeyes with no...
# 33          33  image_captioning/test/uploaded/Popeyes with no...
# 16          16  image_captioning/test/uploaded/Popeyes with no...
# ...

# %%
df.drop_duplicates(subset=["caption"], keep='first')
# Out:
#     Unnamed: 0                                        image_files  \
# 32          32  image_captioning/test/uploaded/Popeyes with no...
# 26          26  image_captioning/test/uploaded/Popeyes with no...
# 29          29  image_captioning/test/uploaded/Popeyes with no...
# 20          20  image_captioning/test/uploaded/Popeyes with no...
# 22          22  image_captioning/test/uploaded/Popeyes with no...
# 9            9  image_captioning/test/uploaded/Popeyes with no...
# 15          15  image_captioning/test/uploaded/Popeyes with no...
# 13          13  image_captioning/test/uploaded/Popeyes with no...
# 11          11  image_captioning/test/uploaded/Popeyes with no...
# 33          33  image_captioning/test/uploaded/Popeyes with no...
# 16          16  image_captioning/test/uploaded/Popeyes with no...
# 30          30  image_captioning/test/uploaded/Popeyes with no...
# 35          35  image_captioning/test/uploaded/Popeyes with no...
# ...

# %%
dupe = df[df["caption"].duplicated() == True]
dupe
# Out:
#     Unnamed: 0                                        image_files  \
# 2            2  image_captioning/test/uploaded/Popeyes with no...
# 6            6  image_captioning/test/uploaded/Popeyes with no...
# 10          10  image_captioning/test/uploaded/Popeyes with no...
# 13          13  image_captioning/test/uploaded/Popeyes with no...
# 14          14  image_captioning/test/uploaded/Popeyes with no...
# 17          17  image_captioning/test/uploaded/Popeyes with no...
# 20          20  image_captioning/test/uploaded/Popeyes with no...
# 23          23  image_captioning/test/uploaded/Popeyes with no...
# 28          28  image_captioning/test/uploaded/Popeyes with no...
# 34          34  image_captioning/test/uploaded/Popeyes with no...
# 35          35  image_captioning/test/uploaded/Popeyes with no...
# 36          36  image_captioning/test/uploaded/Popeyes with no...
#
#                                               caption      prob
# ...

# %%
s = dupe["image_files"].iloc[0].split("/")[-1]

# %%
files = os.listdir("test/uploaded/Popeyes with no bev.mp4/")
files
# Out:
# ['10366.666666666666.jpg',
#  '11366.666666666666.jpg',
#  '10700.0.jpg',
#  '1366.6666666666667.jpg',
#  '6366.666666666667.jpg',
#  '7366.666666666667.jpg',
#  '11700.0.jpg',
#  '3366.6666666666665.jpg',
#  '6033.333333333333.jpg',
#  '2033.3333333333333.jpg',
#  '12033.333333333334.jpg',
#  '3033.3333333333335.jpg',
#  '9700.0.jpg',
#  '2700.0.jpg',
#  '10033.333333333334.jpg',
#  '2366.6666666666665.jpg',
#  '4033.3333333333335.jpg',
#  '11033.333333333334.jpg',
#  '8033.333333333333.jpg',
#  '5033.333333333333.jpg',
#  '1033.3333333333333.jpg',
#  '7033.333333333333.jpg',
#  '1700.0.jpg',
#  '6700.0.jpg',
#  '5366.666666666667.jpg',
#  '8366.666666666666.jpg',
#  '366.6666666666667.jpg',
#  '8700.0.jpg',
#  '9033.333333333334.jpg',
#  '700.0.jpg',
#  '4366.666666666667.jpg',
#  '9366.666666666666.jpg',
#  '33.333333333333336.jpg',
#  '3700.0.jpg',
#  '7700.0.jpg',
#  '4700.0.jpg',
#  '5700.0.jpg']

# %%
timestamps = [float(os.path.splitext(f)[0]) for f in files]

# %%
df.sort_values(by=["timestamps"])
# Out:
#     Unnamed: 0                                        image_files  \
# 32          32  image_captioning/test/uploaded/Popeyes with no...
# 26          26  image_captioning/test/uploaded/Popeyes with no...
# 29          29  image_captioning/test/uploaded/Popeyes with no...
# 20          20  image_captioning/test/uploaded/Popeyes with no...
# 3            3  image_captioning/test/uploaded/Popeyes with no...
# 22          22  image_captioning/test/uploaded/Popeyes with no...
# 9            9  image_captioning/test/uploaded/Popeyes with no...
# 15          15  image_captioning/test/uploaded/Popeyes with no...
# 13          13  image_captioning/test/uploaded/Popeyes with no...
# 11          11  image_captioning/test/uploaded/Popeyes with no...
# 7            7  image_captioning/test/uploaded/Popeyes with no...
# 33          33  image_captioning/test/uploaded/Popeyes with no...
# 16          16  image_captioning/test/uploaded/Popeyes with no...
# ...

# %%
df["timestamps"] = timestamps
df
# Out:
#     Unnamed: 0                                        image_files  \
# 0            0  image_captioning/test/uploaded/Popeyes with no...
# 1            1  image_captioning/test/uploaded/Popeyes with no...
# 2            2  image_captioning/test/uploaded/Popeyes with no...
# 3            3  image_captioning/test/uploaded/Popeyes with no...
# 4            4  image_captioning/test/uploaded/Popeyes with no...
# 5            5  image_captioning/test/uploaded/Popeyes with no...
# 6            6  image_captioning/test/uploaded/Popeyes with no...
# 7            7  image_captioning/test/uploaded/Popeyes with no...
# 8            8  image_captioning/test/uploaded/Popeyes with no...
# 9            9  image_captioning/test/uploaded/Popeyes with no...
# 10          10  image_captioning/test/uploaded/Popeyes with no...
# 11          11  image_captioning/test/uploaded/Popeyes with no...
# 12          12  image_captioning/test/uploaded/Popeyes with no...
# ...
