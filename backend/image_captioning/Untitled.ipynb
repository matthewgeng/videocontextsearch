# %%
import pandas as pd

# %%
# %config Completer.use_jedi = False

# %%
df = pd.read_csv("test/results.csv")

# %%
df
# Out:
#      Unnamed: 0                                        image_files  \
# 0             0  image_captioning/test/uploaded/Popeyes with no...
# 1             1  image_captioning/test/uploaded/Popeyes with no...
# 2             2  image_captioning/test/uploaded/Popeyes with no...
# 3             3  image_captioning/test/uploaded/Popeyes with no...
# 4             4  image_captioning/test/uploaded/Popeyes with no...
# ..          ...                                                ...
# 179         179  image_captioning/test/uploaded/Popeyes with no...
# 180         180  image_captioning/test/uploaded/Popeyes with no...
# 181         181  image_captioning/test/uploaded/Popeyes with no...
# 182         182  image_captioning/test/uploaded/Popeyes with no...
# 183         183  image_captioning/test/uploaded/Popeyes with no...
#
#                                                caption      prob
# 0    a black and white photo of a person holding a ...  0.000033
# ...
